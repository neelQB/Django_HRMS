# %% [markdown]
# ### Docling

# %% [markdown]
# ---
# #### Library Indtallation

# %%
# %pip install docling transformers pypdf pymupdf
# Out:
# Requirement already satisfied: docling in ./.venv/lib/python3.10/site-packages (2.28.4)
# Requirement already satisfied: transformers in ./.venv/lib/python3.10/site-packages (4.51.1)
# Requirement already satisfied: pypdf in ./.venv/lib/python3.10/site-packages (5.4.0)
# Requirement already satisfied: pymupdf in ./.venv/lib/python3.10/site-packages (1.25.5)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in ./.venv/lib/python3.10/site-packages (from docling) (4.13.3)
# Requirement already satisfied: certifi>=2024.7.4 in ./.venv/lib/python3.10/site-packages (from docling) (2025.1.31)
# Requirement already satisfied: docling-core<3.0.0,>=2.24.1 in ./.venv/lib/python3.10/site-packages (from docling-core[chunking]<3.0.0,>=2.24.1->docling) (2.25.0)
# Requirement already satisfied: docling-ibm-models<4.0.0,>=3.4.0 in ./.venv/lib/python3.10/site-packages (from docling) (3.4.1)
# Requirement already satisfied: docling-parse<5.0.0,>=4.0.0 in ./.venv/lib/python3.10/site-packages (from docling) (4.0.0)
# Requirement already satisfied: easyocr<2.0,>=1.7 in ./.venv/lib/python3.10/site-packages (from docling) (1.7.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./.venv/lib/python3.10/site-packages (from docling) (1.2.0)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in ./.venv/lib/python3.10/site-packages (from docling) (0.30.2)
# Requirement already satisfied: lxml<6.0.0,>=4.0.0 in ./.venv/lib/python3.10/site-packages (from docling) (5.3.2)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in ./.venv/lib/python3.10/site-packages (from docling) (2.1.3)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in ./.venv/lib/python3.10/site-packages (from docling) (3.1.5)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in ./.venv/lib/python3.10/site-packages (from docling) (2.2.3)
# Requirement already satisfied: pillow<12.0.0,>=10.0.0 in ./.venv/lib/python3.10/site-packages (from docling) (10.4.0)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in ./.venv/lib/python3.10/site-packages (from docling) (1.5.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in ./.venv/lib/python3.10/site-packages (from docling) (2.11.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in ./.venv/lib/python3.10/site-packages (from docling) (2.8.1)
# Requirement already satisfied: pylatexenc<3.0,>=2.10 in ./.venv/lib/python3.10/site-packages (from docling) (2.10)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.30.0 in ./.venv/lib/python3.10/site-packages (from docling) (4.30.0)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in ./.venv/lib/python3.10/site-packages (from docling) (1.1.2)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in ./.venv/lib/python3.10/site-packages (from docling) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in ./.venv/lib/python3.10/site-packages (from docling) (2.32.3)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in ./.venv/lib/python3.10/site-packages (from docling) (1.4.0)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in ./.venv/lib/python3.10/site-packages (from docling) (1.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in ./.venv/lib/python3.10/site-packages (from docling) (4.67.1)
# Requirement already satisfied: typer<0.13.0,>=0.12.5 in ./.venv/lib/python3.10/site-packages (from docling) (0.12.5)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.10/site-packages (from transformers) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./.venv/lib/python3.10/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in ./.venv/lib/python3.10/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: typing_extensions>=4.0 in ./.venv/lib/python3.10/site-packages (from pypdf) (4.13.1)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.6)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from docling-core<3.0.0,>=2.24.1->docling-core[chunking]<3.0.0,>=2.24.1->docling) (1.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in ./.venv/lib/python3.10/site-packages (from docling-core<3.0.0,>=2.24.1->docling-core[chunking]<3.0.0,>=2.24.1->docling) (4.23.0)
# Requirement already satisfied: latex2mathml<4.0.0,>=3.77.0 in ./.venv/lib/python3.10/site-packages (from docling-core<3.0.0,>=2.24.1->docling-core[chunking]<3.0.0,>=2.24.1->docling) (3.77.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in ./.venv/lib/python3.10/site-packages (from docling-core<3.0.0,>=2.24.1->docling-core[chunking]<3.0.0,>=2.24.1->docling) (0.9.0)
# Requirement already satisfied: semchunk<3.0.0,>=2.2.0 in ./.venv/lib/python3.10/site-packages (from docling-core[chunking]<3.0.0,>=2.24.1->docling) (2.2.2)
# Requirement already satisfied: jsonlines<4.0.0,>=3.1.0 in ./.venv/lib/python3.10/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling) (3.1.0)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in ./.venv/lib/python3.10/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling) (4.11.0.86)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in ./.venv/lib/python3.10/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling) (2.6.0+cu126)
# Requirement already satisfied: torchvision<1,>=0 in ./.venv/lib/python3.10/site-packages (from docling-ibm-models<4.0.0,>=3.4.0->docling) (0.21.0+cu126)
# Requirement already satisfied: scikit-image in ./.venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling) (0.25.2)
# Requirement already satisfied: python-bidi in ./.venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling) (0.6.6)
# Requirement already satisfied: Shapely in ./.venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling) (2.1.0)
# Requirement already satisfied: pyclipper in ./.venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling) (1.3.0.post6)
# Requirement already satisfied: ninja in ./.venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling) (1.11.1.4)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.10/site-packages (from huggingface_hub<1,>=0.23->docling) (2025.3.2)
# Requirement already satisfied: et-xmlfile in ./.venv/lib/python3.10/site-packages (from openpyxl<4.0.0,>=3.1.5->docling) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.4->docling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.4->docling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.4->docling) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->docling) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./.venv/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.3.0->docling) (1.1.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in ./.venv/lib/python3.10/site-packages (from python-pptx<2.0.0,>=1.0.2->docling) (3.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.2->docling) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.2->docling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.2->docling) (2.3.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.10/site-packages (from typer<0.13.0,>=0.12.5->docling) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.10/site-packages (from typer<0.13.0,>=0.12.5->docling) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./.venv/lib/python3.10/site-packages (from typer<0.13.0,>=0.12.5->docling) (14.0.0)
# Requirement already satisfied: attrs>=19.2.0 in ./.venv/lib/python3.10/site-packages (from jsonlines<4.0.0,>=3.1.0->docling-ibm-models<4.0.0,>=3.4.0->docling) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.24.1->docling-core[chunking]<3.0.0,>=2.24.1->docling) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.24.1->docling-core[chunking]<3.0.0,>=2.24.1->docling) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.24.1->docling-core[chunking]<3.0.0,>=2.24.1->docling) (0.24.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.4->docling) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<0.13.0,>=0.12.5->docling) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<0.13.0,>=0.12.5->docling) (2.19.1)
# Requirement already satisfied: mpire[dill] in ./.venv/lib/python3.10/site-packages (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.24.1->docling) (2.10.2)
# Requirement already satisfied: sympy==1.13.1 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (1.13.1)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (3.4.2)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (12.6.85)
# Requirement already satisfied: triton==3.2.0 in ./.venv/lib/python3.10/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from sympy==1.13.1->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (1.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in ./.venv/lib/python3.10/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in ./.venv/lib/python3.10/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in ./.venv/lib/python3.10/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (0.4)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.13.0,>=0.12.5->docling) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->torch<3.0.0,>=2.2.2->docling-ibm-models<4.0.0,>=3.4.0->docling) (3.0.2)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.10/site-packages (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.24.1->docling) (0.70.17)
# Requirement already satisfied: dill>=0.3.9 in ./.venv/lib/python3.10/site-packages (from multiprocess->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.24.1->docling) (0.3.9)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Basic Docling pdf to markdown conversion

# %%
from docling.document_converter import DocumentConverter

source = r"/home/qb-admin/Desktop/ap/BIOS.pdf"
converter = DocumentConverter()
result = converter.convert(source)
md = result.document.export_to_markdown()

print(md)  # output: "## Docling Technical Report[...]"
# Out:
# <!-- image -->
#
# ## PRODUCT MANUAL
#
# <!-- image -->
#
# ## Dear Biosian,
#
# As we all know…
#
# ## ' Knowledge is power '
#
# If  we  have  to  stand  successfully  in  this  competitive  scenario,  we  must  have  to  be  a knowledgeable. In Pharma sales market you are dealing with most knowledgeable persons. For  that first you  have  to  be  a knowledgeable  about  your  products,  science  and competitors.
#
# Think about what is gained by learning more about your product. By knowing more about it  than  your  customers,  competitors  and  other  salespeople  you  will  gain  a  tremendous advantage that will lead to increased sales.
#
# Sales don t always have to be about the prospect ' - being knowledgeable in your product can make you feel accomplished as well.
#
#  Product knowledge builds enthusiasm, gives you courage and the satisfaction of being experts.
#
#  Product  knowledge  also  allows  you  to  speak  with  confidence  around  other experts and helps you respond to any objections properly.
#
#  Product  knowledge  allows  you  to  keep  learning  and  to  discover  additional advantages to offer the prospects.
#
#  Moreover, Product knowledge lets you understand the competition better and gives you self-assurance.
#
# Bios lab takes it initiative to raise your knowledge. This Product Knowledge booklet helps to make you strong by your knowledge.
#
# Be a Knowledgeable... Be a Strong
#
# ## All the best!!
#
# ## ANATOMY &amp; PHYSIOLOGY
#
# -  Pharmacology is  the  branch  of  medicine  concerned  with  the  uses,  effects,  and modes of action of drugs.
# -  Pharmacokinetics is the branch of pharmacology concerned with the movement of drugs within the body. What body does to Drug (Body to Drug).
# -  Absorption, Metabolism, Distribution, Excretion (ADME).
# -  Pharmacodynamics is  the  branch  of  pharmacology concerned with the effects of drugs and the mechanism of their action. What drug does to the body (Drug to Body).
# -  Pharmacological &amp; Therapeutic actions, Uses, Adverse effects etc.
# -  Anatomy is the science deals with the structure of the body and its parts.
# -  Physiology is the science that studies the functions of the normal human body.
# - Cell  The cell is the basic structural, functional and biological unit of body often called the "building blocks of life . '
# -  Tissues are groups of cells with a common structure (form) and function (job).
# -  Tissues  are composed  of  two  major  structural  protein molecules:  Collagen and Elastin.  There  are four  main  tissues in  the  body -Epithelial  tissue,  Connective tissue, Nervous tissue and Muscle 1. Epithelial: lines organs, Includes skin and mucous membranes
# - 2. Connective: supports  and  protects  body  structures,  Includes  adipose (fat) tissue, bone, blood, and cartilage
# - 3. Nervous: conducts electrical impulses to and from the brain and body
# - 4. Muscle: contracts and relaxes to support movement
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# -  Organ is a group of tissues that work together for a common function (Ex: cardiac muscle tissue forms the heart).
# -  Organ System means  groups  of  organs  that  work  together  for  common  function (Ex: heart and blood vessels work together to form the cardiovascular system).
# -  HUMAN BODY: All 11 systems working for their common functions and become a Human body.
#
# <!-- image -->
#
# ## THE 11 HUMAN ORGAN SYSTEMS
#
# - 1) Skeletal System
# - 2) Muscular System
# - 3) Nervous System
# - 4) Cardiovascular OR Circulatory System
# - 5) Respiratory System
# - 6) Digestive System
# - 7) Urinary OR Renal OR Excretory System
# - 8) Reproductive System
# - 9) Endocrine System
# - 10) Lymphatic &amp; Immune System
# - 11) Integumentary OR Skin OR Exocrine System
#
# ## 1) Skeletal System
#
# <!-- image -->
#
# ## SKELETAL SYSTEM
#
# - Supporr
# - Protection
# - Mineral Storage
# - Blood Cells Production
#
# ## 2) Muscular System
#
# <!-- image -->
#
# ## 3) Nervous System
#
# <!-- image -->
#
# ## MUSCULAR SYSTEM
#
# - Locomotion
# - Protection Organ
# - Heat Generation
# - Support Organ
#
# ## NERVOUS SYSTEM
#
# - Homcostasis
# - Directs Responses Stimuli immediately
#
# ## 4) Cardiovascular OR Circulatory System
#
# <!-- image -->
#
# ## 5) Respiratory System
#
# <!-- image -->
#
# ## CARDIOVASCULAR SYSTEM
#
# - Distributes nutricnts, gases, mincrals &amp; hormones
# - Distributes Heat
# - Removes Wastes
#
# ## RESPIRATORY SYSTEM
#
# - Oxygen for body
# - Sound for Communication
# - removal COz
#
# ## 6) Digestive System
#
# <!-- image -->
#
# ## 7) Urinary OR Excretory System
#
# <!-- image -->
#
# ## 8) Reproductive System
#
# <!-- image -->
#
# ## 9) Endocrine System
#
# <!-- image -->
#
# ## DIGESTIVESYSTEM
#
# - Brcaks down food into absorbable units
# - Eliminates indigestible foodstuffs as feces
#
# ## URINARY SYSTEM
#
# - Eliminates nitrogenous
# - Regulates blood volume, &amp; ion concentrations PH
#
# ## REPRODUCTIVESYSTEM
#
# - Perpetuation of species
#
# Life
#
# - Production of hormones for sccondary scxual daracteristics.
# - Male &amp; Female Reproductive Systcm
#
# ## ENDOCRINE SYSTEM
#
# - Homeostasis by slow; term changes in target organs. directing large, long
# - Functional associated with Growth &amp; Maturation Changes
#
# <!-- image -->
#
# ## 10) Lymphatic &amp; Immune System
#
# <!-- image -->
#
# ## LYMPHATICS SYSTEM
#
# Immunological  Defense Return tissuc fluid [o bloodstream
#
# ## 11) Integumentary OR Skin System
#
# <!-- image -->
#
# <!-- image -->
#
# ## TERMINOLOGY
#
# -  pH means the concentration of hydrogen (H + ) ions in a given substance/ solution.
# -  Acid is an excess of Hydrogen (H + ) ions in solution.
# -  Base is a solution that has an excess of hydroxide ions ( - OH) ions in solution.
#
# ## pH Scale:
#
# -  pH  Scale is  a  logarithmic scale used  to  specify  the  acidity  or  basicity  of  an aqueous substance/solution. The pH scale ranges from 0 to 14 .
# -  Acidic solutions  have  pH  values  below  7  OR  0-6.  A  solution  with  a  pH  of  0  is strong acidic.
# -  Basic (Alkaline) solutions have pH values above 7 OR 8-14. A solution with a pH of 14 is strong basic.
# -  A solution with a pH of 7 is neutral. Pure water has a pH of 7.
# -  Homeostasis is the process  to maintenance  of  the  internal  environment (conditions) relatively constant despite changes in external environments.
#
# <!-- image -->
#
# ## INTEGUMENTARY SYSTEM
#
# Protcction Heat Regulation Scnsory Input
#
# -  Homeostasis means Same State or Same conditions.
# -  E.g. : Skin-Temperatures : The external temperature varies during the day and from  season  to  season,  sometimes  by  as  much  as  40 o C,  but  the  human  body temperature stays at about 37 o C
# -  Receptor is a protein molecule that receives chemical signals from outside a cell.
# -  Enzyme: Enzymes are macromolecular biological catalysts. Enzymes accelerate, or catalyze, chemical reactions.
# -  Inhibitor: A substance which slows down or prevents a particular chemical reaction or other process or which reduces the activity of a particular reactant, catalyst, or enzyme.
# -  Blocker: Blocker is someone or something that blocks
# -  Drug: A drug is any chemical entity that causes a change in biological function in a living organism.
# -  Dose: A specific amount of drug prescribed to be taken at one time.
# -  Drug absorption is generally defined as the rate and extent to which the drug moves from its site of administration to its intended target (site) of action.
# -  Half life (t1/2) of Drug: This is the period of time required for the concentration or amount of drug in the body to be reduced by one-half
# -  Bioavailability (BA): The proportion of a  drug  or  substance  which  enters  in  the systemic/blood circulation when introduced into the body and so is able to have an active effect.
# -  Volume of Distribution (Vd): The total Volume of the Body fluid in which a drug appears to be distributed according to its concentration in the blood or plasma.
#
# <!-- image -->
#
# Vd
#
# Total Amount of Drug In the Body
#
# (Volume OF Distribution)
#
# Concentration of drug in the blood plasma
#
# -  Potency is the amount of a drug that is needed to produce a given effect.
# - o E.g., EC50 is the concentration or dose of drug that causes 50% of maximum effect
# - o A highly potent drugs give response at low concentrations, while a drug of lower potency has  the same response only at higher concentrations
# -  Efficacy is the maximum effect that a drug can produce regardless of dose.
#
# - o This maximum effect of drug (EMax) beyond which no further increase in its effect  occurs  even  if  the  dose  of  the  drug  is  increased  to  a  large  amount  is called efficacy or maximal efficacy.
# -  Therapeutic  index: The  ratio  between  median  toxic  dose  (TD50)  and  median effective dose (ED50) is called therapeutic index.
# - o Therapeutic index= TD50/ED50
# -  Tolerability refers  to  the  degree  to  which  overt  adverse  effects  of  a  drug  can  be tolerated by a patient
# -  Adverse Drug Reaction: Drugs may produce two types of effect i.e. Useful effects and  harmful  effects.  Harmful  effects  are  also  known  as  adverse  drug  reaction  or undesired effects. These effects may range from the mild type of adverse effect to severe effects that may cause a death of the person.
# -  Hypersensitivity: An allergic or immunological response to a drug.
# -  Tolerance: Repeated use of a drug causes a gradual decrease in the response to the drug.
# -  Blood Brain Barrier (BBB): It is a tight endothelial cells of the Brain capillaries and Glial cells of the Brain around the blood capillaries that doesn t allow the passage of ' certain  lipid  insoluble  substances  to  pass  from  the  blood  into  the  brain.  Lipid Soluble Drugs can easily cross this Barrier.
# -  Pregnancy Category :
# -  A : Medicine can use in Pregnancy (Pregnant lady)
# -  B : Medicine can use in Pregnancy
# -  C : Medicine can be or cannot be use in Pregnancy
# -  D : Medicine cannot use in Pregnancy
# -  X : Medicine cannot use in Pregnancy
#
# <!-- image -->
#
# ## Medical Abbreviations
#
# | 1   |    |            | By Mouth Orally~   |
# |-----|----|------------|--------------------|
# |     |    |            | Once a day         |
# |     |    |            | day                |
# |     |    | ter in die | day                |
# | 5   |    |            | Four times a day   |
# |     | 9h |            |                    |
# |     | HS |            | sleep sleep        |
# | 8   |    |            | Before meals       |
# |     |    | post cibum | After meals        |
#
# ##  SHORT FORMS:
#
# - o
# - Agonist :  support the process
# - o Antagonist/ Inhibitor : Inhibit or decreases the effect or process
# - o Blocker : Block or Stop the process
# - o Enzyme: Support or essential mediator to complete the process
# - o -cidal : Killing (Eg. Bactericidal, Fungicidal etc,)
# - o -static : Inhibition of growth (Eg. Bacteriostatic, Fungistatic etc,)
# - o -mia: Related to Blood
# - o -ase
#
# :  Enzyme
#
# - o -pathy : Pain due to Damage &amp; inflammation
# - o -itis : Inflammation
# - o Hyper- : More
# - o Hypo- : Low
# - o Myo- : Muscle
#
# ## DIABETES
#
# Glucose is  a  simple sugar that serves as the chief source of energy for the body. Glucose circulates throughout the body via blood.
#
# Glucose,  also  called dextrose ,  one  of  a  group  of  carbohydrates  known  as  simple  sugars (monosaccharides).
#
# - FPG (Fasting Plasma Glucose) or FBS (Fasting blood sugar) - Blood sugar in ' fasting  (not ' eating) for at least 8 hours. Measurement in the morning when you wake up. -Normal FPG (Fasting Plasma Glucose) : 80-110 mg/dl
#
# PPG (Postprandial Glucose) or PPBS (Postprandial blood sugar) - Blood sugar levels about 1 to 2 hours after you eat. It measures blood sugar spikes that happen after you eat.
#
# - -Normal PPG  (Postprandial Glucose) : 110-140 mg/dl
#
# HbA1C (Glycosylated Hemoglobin A1C OR Glycated Hemoglobin A1C) measures how well your blood sugar has been controlled over the past 3 months.
#
# - -Normal HbA1C  (Hemoglobin A1c test)     : 4-6%
#
# ## PANCREAS
#
# The pancreas has important role in regulation of blood glucose levels. It is a glandular organ in the digestive system &amp; endocrine system. Pancreas is a pale grey gland and lies horizontally across the upper part of the abdomen, behind the stomach.
#
# Pancreas produces exocrine and endocrine secretion
#
# - -Exocrine secretionBile  juice  containing  pancreatic  enzymes  &amp;  bicarbonate  that helps in digestion of food.
#
# - -Endocrine secretionHormones like Insulin and Glucagon that helps in regulation of blood glucose levels.
#
# Pancreas: produces insulin and glucagon, pancreatic enzymes
#
# <!-- image -->
#
# ## Islets of Langerhans
#
# -  The pancreatic acinar is a surround groups of cells, called Islets of Langerhans , that produce three different hormones:
# - 2. Beta (β) cells that produce Insulin
# - 1. Alpha (α) cells that produce Glucagon
# - 3. Delta (δ) cells that produce Somatostatin
# - 4. Gamma (γ) cells that  produce pancreatic polypeptide
# -  Pancreas &gt; Islets of Langerhans &gt; Alpha cell secretes Glucagon Hormone &gt; Beta cell secretes Insulin Hormone
# -  Insulin &amp; Glucagon Hormone regulates glucose (sugar) level in the blood.
# - o Insulin keeps blood glucose levels from rising too high
#
# <!-- image -->
#
# <!-- image -->
#
# ## Insulin
#
# - o Glucagon keeps them from falling too low.  Insulin  is  an  endocrine  anabolic  hormone  secreted  from  the  β -cells  in  the  islet  of Langerhans in the pancreas.
#
# -  The active insulin protein consists of two chains of amino acids, A-Chain and BChain that are linked by two disulphide bonds.
# - 1. A-chain contains 21 amino acids
# - 2. B-chain contains 30 amino acids.
# -  It  regulates  protein,  carbohydrate,  fat  metabolism  and  to  some  extent  fluid  and electrolyte balance.
# -  Insulin acts on 3 target tissues : Liver, Skeletal Muscle and Fat or Adipose tissue.
# -  Insulin brings down blood glucose by 3 actions:
# - 1. By promoting uptake of glucose into target cells ;
# - o Glycolysis : Breakdown of Glucose into energy
# - o Glycogenesis : Storage of glucose as glycogen
# - 2. Insulin inhibits gluconeogenesis: New  glucose formation from noncarbohydrate source by the liver ( Hepatic Glucose Production ).
# - 3. By suppressing lipolysis (breakdown of fat).  Insulin Resistance: when cells of the body don t respond properly to the hormone ' insulin. A resistance to the insulin, resulting in increasing blood sugar.
# -  Insulin Sensitivity describes how sensitive the body is to the effects of insulin.
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# ## What is Diabetes?
#
# -  Diabetes Mellitus is known as DIABETES,
#
# ## As per ADA,
#
# Diabetes  Mellitus  is  a  group  of  chronic  metabolic  disorders  characterized  by persistent hyperglycemia (high blood glucose) resulting from defects in :
#
# - 1) Insulin secretion;
# - 2) Insulin action or Both.
# -  Types of Diabetes Mellitus (DM):
# - o Type-1 (Insulin Dependent Diabetes Mellitus -IDDM)
# - o Type-2 (Non-Insulin Dependent Diabetes Mellitus-NIDDM)
# - o Gestational Diabetes Mellitus (GDM)  &amp; Others like LADA, MODY
# - o Latent Autoimmune Diabetes of Adults (LADA)
# - o Maturity onset diabetes of the young (MODY)
# -  Type 1 DM is  a  chronic (lifelong) disease that occurs when the pancreas does not produce enough insulin to properly control blood sugar levels. People with type 1 diabetes must take insulin daily.
# - o Causes:
# -  Pancreas does not produce enough insulin to properly control blood sugar levels because of destruction of pancreatic β cells. An autoimmune disease where the  body's  own  immune  system  attacks and destroys beta cells in the pancreas. The body does not produce enough insulin to control the amount of glucose in the blood.
# -  Type  2  DM is characterized  by  high  blood  glucose  in  the  context  of  insulin resistance  and  relative  insulin  deficiency.  It  is  known  as  Non-Insulin  Dependent Diabetes Mellitus (NIDDM) OR Adult-onset  diabetes,  a  genetic  disorder.  Based  on diet, exercise and medicine type 2 diabetics may not need to take insulin daily
# - o Causes:
# -  Type 2 diabetes occurs when the pancreas doesn't produce enough insulin or the cells of the body become resistant to insulin.
# -  Gestational Diabetes Mellitus (GDM) is diabetes detected for the first time during pregnancy. It is also defined as carbohydrate intolerance of variable severity with onset or first recognition during the present pregnancy .
# -  Prediabetes  / Impaired  glucose  tolerance  (IGT) is  a  condition  in  which  blood sugar is high, but not high enough to be type 2 diabetes.
#
# <!-- image -->
#
# -  Glycaemic control means regulation and maintenance blood glucose levels within normal ranges in diabetic condition.
# -  Glycolysis: The process of breaking down of glucose is called as Glycolysis .
# -  Glycogenesis: The remaining glucose is stored in the liver and muscle as glycogen, and as fat in the adipose tissue. The process of conversion of glucose to glycogen is called as Glycogenesis .
# -  Glycogenolysis: When we are starving (in fasting state) the glucose stored in the liver and muscle as glycogen is converted back to glucose to provide us energy and this process is called as Glycogenolysis.
# -  Gluconeogenesis or Neoglucogenesis: The  formation of glucose from noncarbohydrate sources is called as Gluconeogenesis OR Neoglucogenesis OR Hepatic glucose production .
# -  Lipolysis: If the glycogen stored in the liver and muscle are inadequate to meet the energy requirements then the fat gets depleted and the process of breaking down of fat is called as lipolysis .  Hyperglycemia is  defined as too high a blood sugar (glucose) level. It s a Diabetic ' condition.  Hypoglycemia is defined as a low blood sugar (glucose) level.
# -  Hypokalemia also  spelled  hypokalaemia,  is  a  low  level  of  potassium  (K + )  in  the blood serum. Normal potassium levels are between 3.5 and 5.0 mmol/L.
# -  Morbidity is  the  condition  of  being  ill,  diseased,  or  unhealthy.  E.g.,  In  Diabetes, Morbidity means chances of number of diseases due to Diabetes.
# -  Mortality ,  on  the  other hand, is the  condition of being dead. E.g., Mortality means chances of death due to diabetes and related diseases.
# -  Chronic Kidney Disease (CKD) OR Chronic Renal Failure (CRF) OR chronic renal Disease (CRD) is a condition characterized by a gradual loss of kidney function over time.
# -  Metabolic  Disorders are  genetic  conditions  that  result  in  metabolism  problems. Most people with inherited metabolic disorders have a defective gene that results in an enzyme deficiency.
# -  End Organ Damage or 'target organ damage' usually refers to damage occurring in various major organs like heart, kidneys, brain, and eyes etc.
#
# ## Recommended Targets:
#
# -  American Diabetes Association (ADA) &amp; The American Association of Clinical Endocrinologists (AACE) recommended the target goal guidelines to control blood glucose level,
#
# |             | HbA1C   | FPG          | PPG        |
# |-------------|---------|--------------|------------|
# | Norma Level | 4 - 6 % | <110 mg/Dl   | <140 mg/dL |
# | ADA         | <7 %    | 90-130 mg/dL | <180 mg/dL |
# | AACE        | <6.5 %  | <110 mg/dL   | <140 mg/dL |
#
# Glucose (sugar), measured in mg/dL: milligrams per deciliter
#
# ## Differences between Type-1 &amp; Type-2 DM
#
# | Feature        | Iype-I                                   |                                                                     |
# |----------------|------------------------------------------|---------------------------------------------------------------------|
# |                | IDDM OR Juvenile Diabetes                |                                                                     |
# |                | Younger patients <35 Yr                  | Adult or Older patient >35 Yr                                       |
# |                | Less Common (5-I0% )                     | More common(85-95%                                                  |
# | Plasma Glucose |                                          | High-very high                                                      |
# | Insulin Levels | Absent                                   | High-normal                                                         |
# | Onset          | Acute                                    | Gradual                                                             |
# | Body weight    | Mostlv lean or normal                    | Mostly Obese                                                        |
# | Obesity        | No                                       | Yes 60-90%                                                          |
# | Family History | Present                                  | Strongly_ Present                                                   |
# | Defect         | Absolute insulin Deficiency              | Relative insulin deficiency~ or insulin resistance or both          |
# | Ketosis        | More prone to Diabetic Ketoacidosis (DKA | Less to DKA prone                                                   |
# | Autoantibodics | Usually present                          | Absent                                                              |
# | Management     | Insulin for survival required            | Diet, Exercise; OADs or Insulin (Insulin not required for survival) |
#
# <!-- image -->
#
# BIOS LAB PVT. LTD.
#
# <!-- image -->
#
# BIOS LAB PVT. LTD.
#
# ## Consequences of Diabetes:
#
# <!-- image -->
#
# ## Basic Steps for Type 2 Diabetes care:
#
# - 1. Diet &amp; Exercise
# - 2. Oral monotherapy
# - 3. Oral combination
# - 4. Oral therapy + Insulin
# - 5. Insulin
#
# ## CLASSIFICATION OF ORAL HYPOGLYCEMIC AGENTS (OAD):
#
# ## A. Enhance insulin secretion:
#
# - 1) Sulfonylureas
# - o First generation: Tolbutamide, Tolazamide, Acetohexamide, Chlorpropamide o Second generation: Glimepiride, glibenclamide, glipizide, gliclazide
# - 2) Meglitinide/ phenylalanine analogues
# - o Repaglinide, Nateglinide
# - 3) Glucagon-like peptide-1 (GLP-1) receptor agonists  injectable drugs
# - o Exenatide, Liraglutide, Dulaglutide, Semaglutide
# - 4) Dipeptidyl peptidase-4 (DPP-4) inhibitors / Gliptins
# - o Teneligliptin, Vildagliptin, Sitagliptin, Saxagliptin, Alogliptin, Linagliptin
#
# ## B. Overcome Insulin resistance:
#
# - 1. Biguanide
# - o Metformin
# - 2. Thiazolidinediones
# - o Pioglitazone, Rosiglitazone
#
# ## C. Miscellaneous antidiabetic drugs:
#
# - 1. Alpha-Glucosidase inhibitors
# - o Acarbose, Miglitol, Voglibose
# - 2. Amylin analogue
# - o Pramlintide
# - 3. Dopamine-D2 receptor agonist
# - o Bromocriptin, Cabergoline
# - 4. Sodium-glucose cotransport-2 (SGLT-2) inhibitor / Gliflozins
# - o Dapagliflozin, Canagliflozin, Tofogliflozin, Ertugliflozin etc.
#
# BIOS LAB PVT. LTD.
#
# <!-- image -->
#
# <!-- image -->
#
# ## SODIUM-GLUCOSE COTRANSPORT-2 INHIBITOR (SGLT-2i) (GLIFLOZIN)
#
# ## SGLT2:
#
# - · It is responsible for 80-90%  of renal glucose reabsorption. Renal glucose reabsorption is increased in type 2 diabetes.
# - · SGLT2 is a low-affinity Sodium-Glucose Co-transporter 2. It is responsible for renal glucose reabsorption in the proximal tubule.
# - · Sodium-glucose co-transporter 2 (SGLT2) inhibitors, also called gliflozin drugs, are a new class of diabetic medications indicated for the treatment of type 2 diabetes.
# - -Eg.: Dapagliflozin, Canagliflozin, Empagliflozin
#
# <!-- image -->
#
# BIOS LAB PVT. LTD.
#
# ## Dapagliflozin: A Novel Insulin-Independent approach to Rremove excess glucose
#
# -  3 SGLT2is are Available:
# - o Canagliflozin (Invokana) - 100mg and 300mg
# - o Dapagliflozin (Dapazin/Farxiga) - 5mg and 10mg
# - o Empagliflozin (Jardiance) - 10 and 25mg
#
# ## BIOXIGA ® -10
#
# -  Composition: Dapagliflozin 10mg Tablets
#
# ## DAPAGLIFLOZIN:
#
# -  Class: S odiumgl ucose co- ransporter t 2 i nhibitor (SGLT2i), Gliflozin
# -  Mechanism of action :
# - o Dapagliflozin  is  an  inhibitor  of  SGLT2.  By  inhibiting  SGLT2,  dapagliflozin reduces  reabsorption  of  filtered  glucose  and  thereby  promotes  urinary glucose excretion.
# - o Dapagliflozin also reduces sodium reabsorption and increases the delivery of sodium to the distal tubule.
#
# <!-- image -->
#
# ## Normal Renal Glucose Handling
#
# ##  The benefits of Dapagliflozin s novel mechanism of action: '
#
# - o Dapagliflozin offers an insulin-independent mechanism that can be used as add-on therapy.
# - o Dapagliflozin inhibition of SGLT2 results in daily urinary glucose excretion of approximately 70g,   providing:
# -  Significant and  sustained  HbA1c  reductions  versus  placebo  when added to metformin
# -  The secondary benefit of weight loss
#
# ##  Benefits of Dapagliflozin:
#
# - o Reductions in HbA1c were sustained over 102 weeks
# - o Reductions in FPG
# - o Consistent reduction in HbA1c at Week 24 across
# - o The secondary benefit of weight loss over 102 weeks
# - o Reductions  in  HbA1c with  Insulin  +  Dapagliflozin  compared  with  Insulin  + Placebo at 24 weeks
# - o Uptitration  of  insulin  dosing  is  less  pronounced  in  patients  treated  with insulin + dapagliflozin compared with insulin + placebo ± OADs
# -  Reduction  in  insulin  dose  on  commencement  of  dapagliflozin  to reduce the risk of hypoglycaemia
# - o Reduce the risk of hypoglycaemia
# -  Insulin-independent mechanism of action
# - -Comparable to that of metformin or sitagliptin
# - -Low risk when used as monotherapy
# - -Increased risk with insulin and insulin secretagogues
# -  SGLT2is  lower  the  renal  reabsorption  of  glucose  threshold  without completely inhibiting it
# -  Renal threshold of &lt; 70mg/dL
#
# ##  Side Effects of Dapagliflozin
#
# -  Increased susceptibility to infection / Genital  Infection
# -  Polyuria
# -  Hypotension
# -  Hyperkalemia
# -  Impaired renal function
# -  Increase in LDL
# -  Hypoglycemia when used with a sulphonylurea or insulin
# -  Increased glucose in urine
#
# ## o Urinary Tract Infection risks likely to increase as…
#
# -  Genital Mycotic  &gt;  Urinary Tract Infections (UTIs)
# -  At increased risk:
# -  Dose-independent
# - -Females : 11-15% F &gt; 1-8% M
#
# ## o Kidney Function
#
# ##  Osmotic diuresis &amp; volume depletion
#
# - -Increased risk if &gt; 75yo, eGFR &lt; 60ml/min or on loop diuretics
# - -Polyuria (including nocturia) resulting in dehydration, hypovolemia, syncope, etc.
#
# ##  Dose-dependent decrease in blood pressure
#
# - Systolic BP : 3-6mmHg
#
# - Diastolic BP : 1-2mmHg
#
# 
#
# Bioavailability: 78% (after 10 mg dose)
#
#  Half-Life (t1/2): ~12.9 hours
#
#  Dose : Once a Daily
#
# ##  Precautions for Dapagliflozin:
#
# - o Used together with Diet &amp; Exercise to improve blood sugar control.
# - o It  should  not  be  used  or  used  with  certain  restrictions  to  treat  Type  1 diabetes or Diabetic ketoacidosis (DKA - Increased ketones in your blood or urine).
#
# ##  Advisory Precautions
#
# - o Increase Water Intake
# - o Take care of Genital Hygiene
#
# ##  Additional Benefits of Dapagliflozin
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# - o Remove excess Glucose &amp; it s associated calories via kidney ' o Add on to any current antidiabetic therapy -Starting from Met / SU / DPP / Insulin o Lower risk of worsening heart failure or death from cardiovascular events
# - o Once a Daily Dose
#
# ##  Indication:
#
# - o Type 2 Diabetes Mellitus
# - o Cardiovascular Diseases
# -  Heart  failure  with  reduced  ejection  fraction  to  reduce  the  risk  of cardiovascular death and hospitalization for heart failure (hHF)
# - o Chronic Kidney Disease (CKD)
#
# <!-- image -->
#
# ##  MRP &amp; USP:
#
# - o QR code: 1 st  time in India, Quality Assurance Report &amp; Product details
# - o The Novel &amp; Potent Gliflozin (SGLT2i)
# - o Highly selective SGLT2i for Diabetes
#
# ##  Competitors:
#
# - o Forxiga  10  (AstraZeneca),  Oxra  10  (Sun),  Gledepa  10  (Abbott),  Dapaglyn  10 (Zydus Cadila)
#
# ## BIOXIGA ® -M
#
# -  Composition: Dapagliflozin 10mg  +  Metformin  HCl  500mg  Extended  release Tablets
#
# DAPAGLIFLOZIN: Go through BIOXIGA ® -10
#
# ## METFORMIN:
#
# -  Class: Biguanides
# -  Mechanism of action:
# - o Increases target cell insulin sensitivity by increasing peripheral glucose uptake  &amp; utilization
# - o Decreases hepatic glucose production (Gluconeogenesis)
# - o Decreases GI glucose absorption
# - o Decrease Fatty acid Oxidation by Anti-oxidative properties of metformin on endothelial cells.
# - o Metformin not produces Hypoglycemia &amp; Hyperinsulinemia
#
# <!-- image -->
#
# ##  Indication of Metformin:
#
# - o Type 2 Diabetes Mellitus
# - o Polycystic Ovarian Syndrome (PCOS)
#
# -  Bioavailability: 50-60%
# -  Half-Life (t1/2)  4-9 hours :
# -  Benefits of BIOXIGA ® -M:
# -  Dose: Once a Daily
# -  Indication:
# - o Type 2 Diabetes Mellitus
# - o Cardiovascular Diseases
# -  Heart  failure  with  reduced  ejection  fraction  to  reduce  the  risk  of cardiovascular death and hospitalization for heart failure (hHF)
# - o Chronic Kidney Disease (CKD)
# -  Adverse Effect:
# -  MRP &amp; USP:
# - o QR code: 1 st  time in India, Quality Assurance Report &amp; Product details
# - o The Novel &amp; Potent Gliflozin (SGLT2i)
# - o Highly selective SGLT2i for Diabetes
# -  Competitors:
# -  Visual Aids:
# -  Studies/Trail: DAPA-HF, DAPA-CKD, DECLARE-TIMI
# - o Trail  &amp;  Studies  with  Detailing:  Reference,  Aim,  Types  of  Trail,  No.  of  Patients, Study Period, Conclusion and link with the brand
#
# <!-- image -->
#
# ## INCRETIN &amp; DPP-4i
#
# ## What is Incretin?
#
# -  Incretins are gut hormones that enhance glucose-stimulated insulin secretion and decrease blood glucose levels. The main role of Incretins in Glucose Homeostasis.
# -  Incretins are released after eating in response to a meal and increase the secretion of insulin released  from  pancreatic  beta  cells  by  a  blood  glucose-dependent mechanism.
# -  Incretin effect designates amplification of insulin secretion follows in oral glucose load.
# -  Natural Incretins (Two types):
# - 1. The glucose-dependent insulinotropic polypeptide (GIP)
# - 2. Glucagon-like peptides-1 (GLP-1)
#
# These two hormones are rapidly degraded by an enzyme DPP-4
#
# ## GLP-1 and GIP are the 2 major incretins in human
#
# -  Both are peptide hormones (30 and 42 amino acids)
# -  Released in response to meal ingestion
# -  Secreted from endocrine cells in the small intestinal mucosa
# - · GLP-1 : distal, L-cells (mainly ileum colon , )  GLP-1 is responsible for Ca 2+ channel activation on β -cell and thus increases Insulin production  GLP-1 has short half-life of 2 minutes because of DPP-4  In Type 2 Diabetes -GLP-1 secretion is less &amp; also decrease Incretins effects GLP-1: An Incretin hormone with multiple direct effects on human physiology
# - · GIP : proximal, K-cells (mainly duodenum )
#
# <!-- image -->
#
# Insulin Secretion Mechanism - GLP-1
#
# <!-- image -->
#
# <!-- image -->
#
# ## What is DPP-4?
#
# - · It clears  and  inactivates  Incretins  like  GLP-1  and  GIP  within  few  minutes.  In response to that Blood sugar level increases.
# - · Dipeptidyl  Peptidase-4  (DPP-4)  is  an  enzyme  found  free  in  the  circulation  and tethered  to  endothelium  and  epithelial  cells  in  most  tissues,  especially  in  the intestinal mucosa.
# - · In Type 2 DM , the pancreas doesn't release enough insulin or the body's cells may not use insulin properly.
# - · Gliptins increases the amount of insulin released by the pancreas in order to lower the blood glucose.
# - · This leads to rise in blood sugar level.
#
# ## GLIPTINS - DPP 4 INHIBITORS
#
# ## inspired by life
#
# - ♦ Gliptins or Dipeptidyl peptidase-4 (DPP-4) inhibitors, inhibits DPP-4 enzyme that decreases degradation or inactivation of Incretins like GLP-1 &amp; GIP.
# - ♦ Thus, Increases Incretins effects
# - o Increases Insulin Secretion
# - o Decreases Glucagon Secretion
# - ♦ Dipeptidyl peptidase-4 inhibitors are effective with a low incidence of hypoglycemia and no weight gain either as a single or combination therapy in lowering
# - o Glycated hemoglobin,
# - o Fasting
# - o Postprandial glucose levels.
# - ♦ Once daily ingestion
# - ♦ Reduce fasting and postprandial glucose, reduce HbA1c
# - ♦ Decrease glucagon response to ingested meal
# - ♦ Initial studies in combination with metformin
# - ♦ Mechanism of action :
#
# <!-- image -->
#
# ## Comparisons of Gliptins vs. Traditional Oral Therapies
#
# <!-- image -->
#
# |                  | Pancreas   | Pancreas   | GI    |        |
# |------------------|------------|------------|-------|--------|
# | Agent            | Q          |            | Tract | Tissue |
# | Metformin        |            |            |       |        |
# | Sulfonylurea     |            |            |       |        |
# | TZD              |            |            |       |        |
# | AGI              |            |            | +     |        |
# | DPP-4 Inhibitors |            | +          | 4     |        |
#
# | Therapeutic category       | Drawback                       |
# |----------------------------|--------------------------------|
# | Sulfonylrea                | Hypoglcemia                    |
# | Thiazolidine dione         | Weight gain                    |
# | Insulin                    | Weight= hypoglcemia gain       |
# | Alphaglucosidase inhibitor | Gas, bloaing anddiarrhea       |
# | DPP 4 inhibitors           | Apparentl no sudh side effects |
#
# ## BIOVILDA ®  100 SR
#
# -  Composition : Vildagliptin 100 mg Sustained release Tablets
#
# ## VILDAGLIPTIN:
#
# -  Class: Dipeptidyl peptidase-4 (DPP-4) Inhibitor, Gliptin
#
# ##  Description:
#
# - o Vildagliptin  is  an  orally  active  antihyperglycemic  agent  that  selectively inhibits the dipeptidyl peptidase-4 (DPP-4) enzyme and inhibit it effectively then other Gliptins. It works as an Incretin enhancer.
# - o No adjustment of dose is necessary in either heptic or renal insufficiency.
# - o It has a relatively low risk of hypoglycemia.
# - o Well tolerated &amp; Less adverse effects
# - o Not associated with weight gain
#
# ##  Mechanism of action :
#
# - o Vildagliptin inhibits dipeptidyl peptidase-4 (DPP-4). It inhibits the inactivation of GLP-1 and GIP by DPP-4, allowing GLP-1 and GIP to potentiate the secretion of insulin in the beta cells and suppress glucagon release by the alpha cells of the islets of Langerhans in the pancreas.
# - o Dipeptidyl  peptidase-4's  role  in  blood  glucose  regulation  is  thought  to  be through degradation of GIP and the degradation of GLP-1.
# -  GIP: Glucose dependent Insulinotropic Polypeptide
# -  GLP-1: Glucagon Like Peptide-1
# - o It works by increasing the amount of two incretin hormones in the body that are produced naturally by the body in response to food intake.
#
# <!-- image -->
#
# ##  TECHNOLOGY: BIOVILDA ®  100 SR formulated with Unique technology
#
# <!-- image -->
#
# Provides
#
# Sustained release of Vildagliptin
#
# <!-- image -->
#
# ##  HydroGel Matrix Technology
#
# - o It is a Hydrophilic Matrix tablet Technology.
# - o Formulated by Direct compression method with Hypromellose.
# - o Hypromellose is a Hydrophilic  swellable  polymer  and  also  known  as Hydroxypropyl methylcellulose (HPMC).
# - o It develops an external Gel layer on the surface of matrix tablet and ensures sustained release of Vildagliptin.
#
# ##  What is Hydrophilic Matrix?
#
# - o Hydrophilic  matrix  tablets  are  the  most  frequently  used sustained  release oral dosage forms intended for oral administration.
# - o These hydrophilic matrices have the ability to release the drug over a defined period  of  time,  as  they  do  not  undergo  disintegration  when  delivered  to patients, as the drug is entrapped in the polymeric network at the particulate level.
#
# <!-- image -->
#
# <!-- image -->
#
# ##  Hydrophilic Polymer
#
# - o Stability  and  robustness  of  the  product  is  important  aspect  for  Sustained release Tablet formulation.
# - o Vildagliptin is moisture sensitive drug and there for it has stability issues, to overcome the product stability issues, it is  mixed directly  with hydrophilic polymers of different viscosities.
# - o Biovilda ® 100 SR formulated with Hydrophilic swellable polymer ' Hypromellose  (Hydroxypropyl methylcellulose / HPMC) with combination ' of high viscosity HPMC and low viscosity HPMC at a ratio of about 60:40 to about 90:100. Among these, high viscosity polymer is directly compressible grade with excellent flow properties.
#
# ##  Direct Compression Method
#
# - o Furthermore, Wet granulation and Dry granulation method which are used in Tablet formulation, which may impact in the release profile of Vildagliptin.
# - o So, we have used Direct compression method with Hypromellose (HPMC) in Biovilda ®  100 SR.
# - o It is benefited in the following way
# -  Formulate stable and robust sustained release tablet
# -  Safer for moisture-sensitive Vildagliptin
# -  No impact in the release profile of Vildagliptin
#
# ##  In BIOVILDA ®  100 SR,
#
# - o We have used swellable polymer as Hypromellose (Hydroxypropyl methylcellulose/HPMC).
# - o It  provides  good  compression  properties, adequate  swelling  characteristics which allow the matrix tablet to develop an external gel layer on the surface of matrix tablet, non-toxic nature, ability to give pH independent drug release profiles and amenability to high levels of drug loading.
# - o Polymer swelling,  drug  dissolution  and  matrix  erosion  are  the  phenomena that  determine  the  mechanism  of  drug  release  from  hydrophilic  matrix tablets.
# - o When drug loaded swellable cellulose ethers based hydrophilic matrices are exposed to dissolution fluid, steep water concentration gradients are formed between the dissolution fluid and the outermost surface of matrix tablet.
# - o This results in water imbibition into the polymer matrix network
#
# <!-- image -->
#
# <!-- image -->
#
# tablet surface
#
# 24 hours
#
# -  In BIOVILDA ®  100 SR
# - o Ensures &gt; 80% DPP4 enzyme Inhibition at every single hour point
# - o Comparison of % DPP4 enzyme inhibition with BID Dose
# - o Comparison of Average % DPP4 enzyme inhibition with BID Dose (0-24 hours)
#
# <!-- image -->
#
# <!-- image -->
#
# - o Offers sustained Action with effective control in T2DM  Patients with HbA1c &gt; 8%
#
# <!-- image -->
#
# ##  What is Sustained Release?
#
# - o Sustained release (SR) means release of a drug substance at an adequately slow  or  controlled  rate  over  a  sustained  period,  thus  a  minimum  effective concentration of medication can provide long-term therapeutic effects after administration of a single dose. Time depends on the dosage form.  In  oral form  it  is  in  hours,  and  in  parenteral s  it  is  in  days  and months. ' o Advantages:  Decreased local and systemic side effects
# -  Better drug utilization
# -  Improved efficiency in treatment
#
# <!-- image -->
#
# ## Ensures Victory Over Diabetes
#
# - 24 No Change to 24 hours Insulin Secretors
# - DAL Once a Daily Dose
# - Rapidly Absorbed
# - High Bioavailability
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# ##  Benefits of Vildagliptin
#
# - o Reduces PPG, FPG
# - o Reduces Overnight HGP
# - Reduces HbAIc by 0.6-1.1%
# - Improves Patient Compliance
# - Reduces the pill burdens
# - Cost effective
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# <!-- image -->
#
# - o Reduces Insulin Resistance
# - o Low risk of Hypoglycemia
# - o Not associated with weight gain (Weight Neutrality)
# - o Improves -cell sensitivity in both hyper and hypoglycemia
# - o Significantly reduces oxidative stress than Sitagliptin
# - o No Bilirubin elevation
#
# α
#
# - o No Acute OR Severe side effects with normal renal &amp; mild renal impaired patients
# - o Well tolerated &amp; Less adverse effects
#
# ##  Dosage &amp; Administration of Vildagliptin:
#
# - o Vildagliptin is taken orally and likely to be administered 50 mg BID OR 100mg OD.
# -  With metformin or a thiazolidinedione: 50 mg twice daily;
# -  With sulfonylurea: 50 mg/day in the morning.
# -  Maximum Dose: 100 mg/day.
#
# ## o A dose of 50-100mg of  Vildagliptin provides:
#
# -  Almost complete inhibition of DDP-4 for approximately 12 hours
# -  About 40% inhibition by 24 hours
#
# ##  Contraindications of Vildagliptin:
#
# - o Type 1 diabetes
# - o Diabetic ketoacidosis
# - o Severe liver impairment
# - o During pregnancy &amp; Breastfeeding.
# -  Bioavailability: 85%
# -  Half-Life (t1/2): 2-4 hrs
# -  Dose : Once a Daily
#
# ##  Indication:
#
# - o Type 2 Diabetes Mellitus
# - o Diabetes with or without obesity
#
# ##  MRP &amp; USP:
#
# - o QR code: 1 st  time in India, Quality Assurance Report &amp; Product details
# - o HydroGel Matrix Technology
# - o Once a Daily (OD) Dose
# - o Benefits of Hypromellose (HPMC) Polymer
# - o Registered brand
#
# ##  Competitors:
#
# - o Zava  OD  10  / Intaglip  OD  100  (Intas),  Vysov  XR  100  (Cipla),  O  Vildalog  SR (Wockhardt), Vilatin 100 SR (Ajanta)
#
# ## Life
#
# <!-- image -->
#
# ## BIOVILDA ® -MSR
#
# -  Composition : Vildagliptin 50 mg + Metformin HCl 500 mg Sustained release Tablets
#
# VILDAGLIPTIN:
#
# Go through BIOVILDA ®  100 SR
#
# METFORMIN: Go through BIOXIGA ®  -M
#
# <!-- image -->
#
# <!-- image -->
#
# ##  Indication:
#
# - o Type 2 Diabetes Mellitus
#
# ##  MRP &amp; USP:
#
# - o 1 st in Bharat Vocal for Local
# - o Revolution in Vilda + Metformin combination with Sustained release form
# - o Better bioavailability, Better efficacy &amp; Better compliance
#
# -
#
# - o QR code: 1 st  time in India, Quality Assurance Report &amp; Product details
#
# ## BIOVILDA ® -50
#
#  Composition : Vildagliptin 50 mg Tablets
#
# VILDAGLIPTIN:
#
# Go through BIOVILDA ®  100 SR
#
# ##  MRP &amp; USP:
#
# - o QR code: 1 st  time in India, Quality Assurance Report &amp; Product details
# - o Registered brand
# - o The Most effective Gliptin
#
# ## BIOVILDA ® -M
#
# -  Composition : Vildagliptin 50 mg + Metformin HCl 500 mg Tablets
# -  MRP &amp; USP:
# - o QR code: 1 st  time in India, Quality Assurance Report &amp; Product details
# - o The Most effective Gliptin
# - o Registered brand
#
# VILDAGLIPTIN:
#
# Go through BIOVILDA ®  100 SR
#
# METFORMIN:
#
# Go through BIOXIGA ®  -M
#
# ## BIOTENLY ® -20
#
# -  Composition: Teneligliptin 20mg Tablets
#
# ## TENELIGLIPTIN:
#
# -  Class: Dipeptidyl peptidase-4 (DPP-4) Inhibitor, Gliptin
#
# ##  Teneligliptin: The Number 1 Gliptin
#
# - o A  novel  and  potent  Gliptin  (DPP-4  inhibitor)  with  a  preferable  profile  in terms of long-term efficacy and safety.
# - o Teneligliptin  has  highest  potency,  long  half-life,  Safety  in  renal  &amp;  hepatic patients.
# - o Teneligliptin  work  on  Alpha  &amp;  Beta  both  cells  and  Decrease  secretion  of Glucagon &amp; Increase secretion of Insulin.
# - o Effectively improves beta cell function and decreases insulin resistance.
# - o Gives potent and sustained effects on glycemic control and reduces diabetic complications.
# - o Shows significant improvement in lipids profiles along with improvement in blood glucose &amp; HbA1c level.
# - o Effectively enhances  adiponectin  (Protein  in Adipose  tissue) levels to regulate insulin sensitivity &amp; energy homeostasis.
#
# <!-- image -->
#
# <!-- image -->
#
# ##  Mechanism of action :
#
# - o In  response  to  a  food,  active  Glucagon-like  peptide-1  (GLP-1)  &amp;  Glucosedependent  insulinotropic  polypeptide  (GIP)  like  Incretin  hormones  are secreted by the L cells of the intestines.
# - o Without  the  presence  of  a  Gliptin,  GLP-1  &amp;  GIP  is  rapidly  inactivated  and degraded by the enzyme dipeptidyl peptidase-4 (DPP-4).
# - o When a Teneligliptin is present, it  binds  to  DPP4,  allowing  GLP-1  &amp;  GIP  to remain active.
# - o Active GLP-1 &amp; GIP increases insulin secretions by pancreatic beta cells and decrease glucagon secretions by pancreatic alpha cells that decrease Blood Glucose level.
#
# ## o Teneligliptin-
#
# -  Increases Incretin Hormones level thus...
# -  Increases Insulin secretion
# -  Decrease Glucagon secretion
# -  Decrease Hepatic Glucose Production
# -  Improves Beta Cell Function
# -  Delay Gastric Emptying
# -  Increase satiety (feeling of fullness &amp; the suppression of hunger)
#
# <!-- image -->
#
# ##  Advantages Of Teneligliptin
#
# ## I LONGER DURATIONOF ACTION
#
# The duationof actionofa is knownasitshalf life-Thisis the in the body to be reduced by onc-half. drug drug
#
# <!-- image -->
#
# |                                                                             |
# |-----------------------------------------------------------------------------|
# |                                                                             |
# |                                                                             |
# |                                                                             |
# |                                                                             |
# | Teneligliptin : 24 hrs duration of action, Round the Clock Glycemic control |
#
# ## 2. Lowest ICso
#
# The half maximal linhibitory concentration (ICso) is a mceasue of the potency of a substancein inhibiting a biologicalor biochemical function specific
#
# | DPP 4 INHIBITOR   | DPP-4 Inhibition; ICSO (nmol/L)   |
# |-------------------|-----------------------------------|
# | Vildagliptin      | 29.2                              |
# | Saxagliptin       | 6.3                               |
# | Alogliptin        | 4,9                               |
# | Sitagliptin       | 10.3                              |
# | Teneligliptin     | 0.37                              |
#
# ## TENELIGLIPTIN : LOWEST ICsO: HIGH POTENCY
#
# ## 3. ANCHOR LOCK STRUCTURE
#
# <!-- image -->
#
# Unique Anchor Lock Structure provides : to the DPP 4 Enzyme specificBinding E
#
# ## 4.EXCRETION
#
# | DPP 4 INHIBITOR                       | EXCRETIONINURINE   | EXCRETIONINFECES   |
# |---------------------------------------|--------------------|--------------------|
# | Teneligliptin                         | 45.4%              | 46.5%              |
# | Linagliprin                           | 5"                 | 8.5%               |
# | Saxagliptin                           | 6.50               | 2.200              |
# | Sitagliptin. Vildagliptin; Alogliptin |                    |                    |
#
# Balanced Excretion from &amp; Liver Highest Renal &amp; Hepatic among the Kidney : Safety Group
#
# ## 5.NO DOSAGE ADJUSTMENT INRENAL &amp; HEPATIC IMPAIRMENT
#
# | HEPATIC   | subjects (n = 8)   | (n         | (n                                 | Subjects with moderate hepatic   | Subjects with moderate hepatic   |
# |-----------|--------------------|------------|------------------------------------|----------------------------------|----------------------------------|
# | Parameter | Mean               | (SD)       | Geometric least squares mean ratio | (SD)                             |                                  |
# |           |                    |            | 125.5                              | (113.0)                          |                                  |
# | AUCo-,    |                    | (781.0     | 149.5                              |                                  | 162.7 [135.3. 195.6]             |
# | (ng-hlmL) | (209.1)            | (790.0)    | 145.9 [122.1 . 174.2]              | (505 8)                          | [133.5. 190.4]                   |
# | (h)       | (6.4)              | 27.9 (7.1) | 121.6                              | 30.9 (6.6)                       | 137.6 [106.5. 177.7]             |
# | (h)       | 1.00               | 0.75       |                                    | 0.50                             |                                  |
#
# ##  Pharmacokinetic comparisons of Gliptins
#
# | PARAMETER        | TENELIGLIPTIN   | VILDAGLIPTIN   | SITAGLIPTIN   |
# |------------------|-----------------|----------------|---------------|
# | ROUTE            | Oral            | Oral           | Oral          |
# | BIOAVAILABILITY  | 63-85.5%        | 87%            | 85%           |
# | Max              | 1.33 hour       | 1 I4hour       | I.7hour       |
# | HALF-LIFE (t1/2) | 24.2 hour       | 2-3 hours      | 3 hours       |
# | PPB              | 78-80%          | 38%            | 9.3%          |
# | EFFECT ONFOOD    | NIL             | NIL            | NIL           |
# | DRUG INTERACTION | NIL             | Digoxin        | LOW           |
# | DOSAGERANGE      | 20 mg 40 mg     | 5Omg IOOmg     | 5Omg IOOmg    |
#
# ##  Benefits of Teneligliptin over other Gliptins
#
# - o Teneligliptin provides strongest binding to DPP-4 enzymes as compared to other gliptins.
# -  Longer duration of action: 24 hrs duration of action, round the clock glycemic control
# -  Anchor  lock  structure: Unique  anchor  lock  structure provides specific binding to the DPP -4 enzyme  Excretion : balanced excretion from kidney &amp; liver  Highest renal &amp; hepatic safety among the group
# ...
# -  That suppresses the final step in gastric acid production by binding two sites of  the  H + K + ATPase enzyme system and due to it decrease Acid secretion in stomach .
# -  Binds to H + /K +   exchanging  ATPase  pump  (proton  pump)  in  gastric parietal cells resulting in blocking acid secretion.
# -  Bioavailability: 52%
# -  Half-Life (t1/2) : 1-2 hr depending on dose
# -  General dose: Rabeprazole 20 mg (1 Tablet) Per Day before meal for up to required time.
# -  Pregnancy category: B
# -  Side effects: Diarrhea, Headache, Rhinitis, Nausea, Pharyngitis, Abdominal pain
# -  Indication: Acidity, GERD, Dyspepsia
# -  MRP &amp; USP:
# -  Competitors:
#
# <!-- image -->
#
# ## RZOLE™ -D/ DSR
#
# ##  Composition:
#
# - o R-ZOLE-D: Rabeprazole Sodium 20mg + Domperidone 10mg Tablets
# - o R-ZOLE-DSR: Rabeprazole Sodium 20mg + Domperidone 30mg SR Capsules
#
# RABEPRAZOLE:
#
# Please go through R-ZOLE TM -20
#
# DOMPERIDONE:
#
# Please go through XEOZIA TM -RD
#
# ##  General dose :
#
# -  R-Zole-D: 1 Tablet qDay before breakfast in the morning for 4-8 week can raise the dose till 1 tab T.I.D (Domperidone 10mg)
#
# -  R-Zole-DSR: 1 Capsule qDay before breakfast in the morning for 4-8 week (OD) (Domperidone 10mg)
# -  Indication: Acidity, GERD, Dyspepsia, Gastritis with Nausea &amp; Vomiting
# -  MRP &amp; USP:
# -  Competitors:
# -  Composition:
#
# ## R-ZOLE-L ™/ L-URIDE ™
#
# - o R-ZOLE-L: Rabeprazole Sodium 20mg + Levosulpiride 75mg Capsules
# - o L-URIDE: Levosulpiride 25mg Tablets
#
# RABEPRAZOLE:
#
# Please go through R-ZOLE TM -20
#
# ## LEVOSULPIRIDE:
#
# -  Class: GIT Regulators, Antiflatulents &amp; Anti-Inflammatory
# -  Mechanism of action:
# -  Levosulpiride is a substituted benzamide, which exerts antidopaminergic (Inhibit selective dopamine D2 receptors) activity on both central and peripheral levels.
# -  It is an atypical neuroleptic and a prokinetic agent.
# -  Also acts as agonist of 5-HT-4 receptors, hence inhibits Acholine Esterase enzyme.
# -  It regulates GI Motility and helps to control gastric emptying.
# -  Bioavailability: 30%
# -  Half-Life (t1/2) : 9.7 hr
# -  Pregnancy category: B
# -  Dose: 1 Tablet PO qDay before meal (OD)
# -  Maximum dose of Levosulpiride 75mg/day before meal
# -  If  Levosulpiride is given 25mg in tablet then dose can raises till 1 tab T.I.D
# -  Indication: Restore GI Motility, Gastroparesis &amp; Stomach ulcers
#
# <!-- image -->
#
# -  MRP &amp; USP:
# -  Competitors:
#
# ## B-SOX ™
#
# -  Composition: Sucralfate 1gm + Oxetacaine 20mg/10 ml gel suspension
#
# ## SUCRALFATE:
#
# -  Class: Gastro-protective agent, Cytoprotective agent
# -  Description:
# - -Cytoprotection is a process by which chemical compounds provide protection to cells against harmful agents. For example, a gastric cytoprotectant is any medication that combats ulcers not by reducing gastric acid but by increasing mucosal protection.
#
# ##  Mechanism of action:
#
# -  Forms  ulcer-adherent  complex  at  injured  sites;  protects  ulcer  from  acid, pepsin, and bile salts, enhances epithelial restitution process, thus allowing it to heal.
# -  Protects  these  areas  from  pepsin,  which  normally  breaks  down  proteins (making ulcers worse).
# -  Attracted  to  and  binds  to  the  base  of  ulcers  and  erosions,  forming  a protective barrier over these areas.
# -  Bioavailability: 5%
# -  Indications:
# -  Duodenal ulcer
# -  Stress ulcer
# -  Peptic ulcer
#
# <!-- image -->
#
# ## OXETACAINE:
#
# -  Class: Local anesthetic drug
# -  Mechanism of action:
#
# -  Oxetacaine  (also  known  as  oxethazaine)  is  a  potent  local  anesthetic.  It  is administered orally (usually in combination with an antacid) for the relief of pain  associated  with  peptic  ulcer  disease  or  esophagitis.  It  is  also  used topically in the management of hemorrhoid pain.
# -  Unlike  most  local  anesthetics,  oxetacaine  does  not  break  down  under strongly acidic conditions.
# -  Local anesthetic (LA) is a medication that causes reversible absence of pain sensation, although other senses are often affected as well.
#
# ##  Indications:
#
# -  Duodenal ulcer
# -  Stress ulcer
# -  Peptic ulcer
# -  MRP &amp; USP:
# -  Competitors:
#
# ## IMMUNOSUPPRESSANT
#
# ## IMMUNE SYSTEM:
#
# <!-- image -->
#
# -  The Immune system is body's defense system (Body guard) and it protect the body against infectious pathogenic viruses, bacteria, and fungi etc.
# -  The Immune system works to keep these harmful agents out of the body and attacks those that manage to enter.
#
# ##  Structures:
#
# - o White blood cells
#
# ## inspired by life
#
# - o Thymus
# - o Spleen
# - o Lymph nodes
# - o Lymph vessels
# -  Immunity  is  a  state  in  which  the  body  has  sufficient  defenses  to  fight  infection, disease or invasion by pathogens.
#
# <!-- image -->
#
# -  A pathogen is a bacterium, virus, or other microorganism that can cause disease.
#
# ##  Function:
#
# - o Helps protect the body from disease; collects fluid lost from blood vessels and returns the fluid to the circulatory system
#
# ##  Antigen:
#
# - o A  toxin  or  harmful  substance  or  pathogen  or  other  foreign  substance  which induces an immune  response  in  the body, especially the production of antibodies.
# - o An antigen is any substance that when introduced into the body stimulates the production of an antibody immune response.
#
# ## o Antigens include:
#
# -  Toxins
# -  Bacteria
# -  Foreign blood cells
# -  Cells of transplanted organs
#
# ##  Antibody (Ab):
#
# - o Antibodies are special proteins that recognize and defeat invading pathogens.
# - o Antibody  (Ab) also  known  as  an  immunoglobulin  (Ig),  is  a  large,  Y-shaped protein produced mainly by plasma cells that is used by the immune system to identify and neutralize pathogens such as bacteria and viruses.
# - o Antibodies are made by the B-cells.
# - o Once a pathogen is encountered by the B-cells it memorizes it and next time it encounters the pathogen it will have antibodies ready to fight the pathogen.
# - o Antibodies or Immunoglobulin (Ig) that have important role in Immune System are,
# -  IG G
# -  IG A
# -  IG M
# -  IG D
# -  IG E
#
# <!-- image -->
#
# ## o Other Immune System cells:
#
# -  White Blood Cells (WBC): Neutrophills etc.
# -  Lymphocytes (Lymphatic System): T Cells  &amp; B Cells
#
# ## AUTOIMMUNE DISORDER:
#
# -  An  autoimmune  disorder  means  when  the  body's  immune  system  attacks  and destroys healthy body tissue by mistake OR an autoimmune disease is one in which the body's immune system mistakenly attacks normal cells.
# -  An autoimmune disease develops when your immune system, which defends your body  against  disease,  decides  your  healthy  cells  are  foreign.  As  a  result,  your immune system attacks healthy cells.
# -  There are more than 80 types of autoimmune disorders.
# - o Psoriasis
# - o Vasculitis
# - o Myasthenia gravis
# - o Rheumatoid arthritis
# - o Multiple sclerosis (MS)
# - o Type 1 diabetes mellitus
# - o Guillain-Barre syndrome
# - o Neuromyelitis optica (NMO) / Devic's disease
# - o Systemic lupus erythematosus (Lupus)
# - o Inflammatory bowel disease (IBD)
# - o Chronic inflammatory demyelinating polyneuropathy
#
# <!-- image -->
#
# ## IMMUNOSUPPRESSANT:
#
# - o Immunosuppressant drugs inhibit  cellular/humoral  or  both  immune  response and have their major use in organ transplantation and auto immune diseases.
# - o These  drugs  have  met  a  high  degree  of  success  in  organ  transplant  and autoimmune diseases.
# - o However,  such  therapies  require  life  time  use  and  non-specifically  suppresses the entire immune system
# - o A narrow therapeutic index.
# - o Therapeutic monitoring plays a key role in maintaining plasma n blood levels of the drug.
# - o Variation  in  concentration  outside  narrow  therapeutic  range  can  result  in adverse effects.
# - o Concentrations are not too high or low, thereby reducing the risks of toxicity or rejection.
#
# ## BIO-MMF TM
#
# -  Composition: Mycophenolate mofetil 500 mg Tablets
#
# ## MYCOPHENOLATE MOFETIL:
#
# -  Class: Immunosuppressive agents / Immunosuppressant
# -  Description:
#
# - o It is an immunosuppressive agents used to lower the body's natural immunity in patients who receive organ transplants.
# - o It is a semisynthetic derivative of mycophenolic acid from fungus source.
# - o Prodrug; is hydrolyzed to mycophenolic acid.
#
# ##  Mechanism of action:
#
# - o MMF is a semisynthetic derivative  of  MPA  (Mycophenolic  acid).  It  is  a  potent, reversible &amp; selective agent and it is a Non-competitive inhibitor of the enzyme inosine monophosphate dehydrogenase (IMP).
# - o This  drug  is  rapidly  converted  to  mycophenolic  acid  and  it  inhibits de  novo synthesis  of  purines  by  inhibiting  inosine  monophosphate  dehydrogenase,  an enzyme  in  the  de  novo  pathway  of  purine  synthesis.  It  is  crucial  for  purine synthesis.
# - o This action
# -  Suppresses  both  B  and  T  cells  of  nucleic  acids  (B  and  T  lymphocyte activation).
# -  Lymphocytes  are  particularly  susceptible  to  inhibitors  of  the  de  novo pathway because they lack the enzymes necessary for the alternative salvage pathway for purine synthesis.
# -  Bioavailability: 94% (mofetil), 72% (sodium)
# -  Half-Life  t1/2 ( )  17.9±6.5 hours :
# -  Pregnancy category: D
#
# <!-- image -->
#
# ##  Dose:
#
# o Twice daily (BID) on an empty stomach, 1 hour before or 2 hours after meals. o Renal Transplantation  ADULTS: PO/IV 1 g administered over ≥2 hours bid (daily dose of 2 g). o Cardiac Transplantation
#
#  ADULTS: PO/IV 1.5 g administered over ≥ 2 hours bid (daily dose of 3 g). o Orally : (twice a day )  Oral tablet: 500 mg
#
# -  Oral capsule: 250 mg
# -  Oral powder for suspension: 200 mg/ml
# - o Intravenous: 500 mg vial to be reconstituted in 14 ml of D5W.
#
# ##  Indication:
#
# - o It used to prevent  the body  rejection of a solid organ transplant such as :
# -  Kidney
# -  Heart
# -  Liver
# -  Lunge and Pancreas
# - o In treatment of uveitis
# - o In treatment of nephritis
# - o In the treatment of several types of vasculitis
# - o Treatment of psoriasis
# -  MRP &amp; USP:
# -  Competitors:
#
# ## BIO-AZAPIN TM  50
#
# -  Composition: Azathioprine 50 mg Tablets
#
# ## AZATHIOPRINE:
#
# -  Class: Immunosuppressive agents / Immunosuppressant
# -  Description:
# - o Azathioprine, a Synthetic Mercaptopurine  (6-MP)  analog of Adenine and Hypoxanthine (Purine derivatives).
# - o It is a Pro-drug, converted in the body to the active metabolite 6mercaptopurine.
# -  Purines are natural substances found in all of the body's cells.
# -  Purines provide part of the chemical structure of our genes and the genes of plants and animals.
# -  Adenine,  Guanine  and  Hypoxanthine  are  Purine  derivatives  and  Purine Synthesis is responsible for DNA/RNA multiplications.
# -  Purines  break  down  into  uric  acid,  a  substance  that  can  help  protect  our blood vessels from damage and that is a common recycled product when our cells die.
#
# ## Life
#
# <!-- image -->
#
# - o Azathioprine is a Potent Immunosuppressive agent as well gives Anti Inflammatory  action.    It  helps  to  reduces  inflammations  &amp;  damages  of  nerve fibers.
# - o Azathioprine has strong anti-inflammatory properties. It reduces the numbers of circulating monocytes by inhibition of proliferation.
# - o It is a safe and effective drug used alone in certain autoimmune diseases such as rheumatoid arthritis, Neuro disorders.
# - o The  mechanisms  whereby  Azathioprine  affects  autoimmune  diseases  are  not known.
#
# ##  Mechanism of action:
#
# - o Azathioprine acts to inhibit purine synthesis ( Purine synthesis inhibitor/ antagonizes purine metabolism) and It may inhibit synthesis of DNA, RNA, and proteins that is  necessary  for  the  proliferation  of  cells,  and  thus  inhibitions  of cell  proliferation.  Especially  fast-growing  cells  without  a  method  of  nucleotide salvage ("recycling"), such as leukocytes and lymphocytes.
# - o It may also interfere with cellular metabolism and inhibit Mitosis (Cell division).
# - o Two  types  of  lymphocytes,  T cells  and  B cells  of  the  immune  system,  are particularly affected by the inhibition of purine synthesis
# -  Bioavailability: 60 ± 31%
# -  Half-Life  t1/2 ( )  26 : 80 minutes
# -  Pregnancy category: D
# -  Dose:
#
# <!-- image -->
#
# -
#
# - o The initial dose should be approximately 1.0 mg/kg ( 50 to 100 mg) given as a single dose or on a twice-daily schedule
#
# ##  Indication:
#
# - o Vasculitis
# - o Psoriasis
# - o Rheumatoid Arthritis
#
# - o Kidney Transplantation
# - o Lupus Nephritis
# - o Ulcerative Colitis
# -  MRP &amp; USP:
# -  Competitors:
#
# ## Gestational Diabetes Mellitus (GDM)
#
# All Pregnant Indian women need to be screened for Gestational Diabetes Mellitus (GDM)
#
# ## 1 st Time in India,
#
# <!-- image -->
#
# Anhydrous Glucose 75 gm Powder
#
# ## What is Gestational Diabetes Mellitus (GDM)?
#
# - o Gestational  diabetes Mellitus is  a  condition  in  which  a  woman  without diabetes  develops  high  blood  sugar  levels  during  pregnancy.  GDM  is  also known as Genetic Diabetes.
# - o Gestational diabetes mellitus is a condition in which a hormone made by the placenta prevents the body from using insulin effectively.
# - o Gestational diabetes risk factors include being overweight or obese, history of Gestational diabetes in a previous pregnancy, and PCOS.
#
# ## Oral Glucose Tolerance Test (OGTT)
#
# - o Test  done  to  assess  the  ability  of  the  body  to  tolerate  extra  glucose  taken orally hence known as Oral glucose tolerance test (OGTT).
# - o The oral glucose tolerance test (OGTT) measures the body's ability to use a type of sugar, called glucose, which is the body's main source of energy. An OGTT can be used to diagnose pre diabetes and diabetes.
# - o GTT  or  OGTT  is  well  standardized  test,  and  is  highly  useful  to  diagnose diabetes mellitus in doubtful cases.
#
# <!-- image -->
#
# - o GTT  Test  is  most  commonly  done  to  check  for  diabetes  that  occurs  with pregnancy (Gestational diabetes).
#
# ## Principle
#
# - o In  normal  individuals  pancreatic  insulin  secretion  maintains  blood  glucose within a tight concentration range following an oral glucose load. Failure of insulin secretion, or resistance to insulin action, will result in an elevation in blood glucose.
#
# ## Screening (Diagnosis) for GDM
#
# - o Asian Indians are a high risk ethnic group for development of Diabetes.
# - o Hence all pregnant Indian women need to be screened for GDM.
#
# ## When to Screen
#
# - o GDM usually develops during late Pregnancy (After the first trimester)
# - o However  if  screening  is  delayed  till  that  time,  there  is  a  chance  that  preexisting diabetes may be missed.
#
# ## As per,
#
# <!-- image -->
#
# - o ADA ( American Diabetic Association ): As early  as  possible  in  pregnancy,  if negative, retest between 24 to 28 weeks.
# - o DIPSI ( Diabetes in Pregnancy Study Group India) : First screening at the first contact visit, if negative repeat at 24 to 28 weeks.
#
# ## Dose in Adults
#
# - o 75  gm  anhydrous  glucose  in  cold  water.  The  solution  should  be  chilled  to improve  palatability,  which  is  more  palatable  and  should  be  followed  by 150mL water (Total volume should be 250-300mL)
# - o 75gm of  oral  dose  is  the  recommendation  of  the WHO to  be  used  in  all adults.
# - o In oral  glucose  tolerance  test  (OGTT), a  standard  dose  of  glucose is ingested by mouth and blood levels are checked two hours later.
# - o This test should be performed in the morning. Patients should be in fasting state.
#
# ## Diagnosis of GDM
#
# - o A zero time (baseline) blood sample is drawn (0 min)
# - o 75 gm Anhydrous Glucose load (solution should be drunk within 5 minutes)
# - o Sample collected after 2 hrs (60 min)
#
# ## Result
#
# |           | 2 hours Plasma Glucose (mg/dl)   | Category   |
# |-----------|----------------------------------|------------|
# | WHO&DIPSI | 140-199                          | GDM        |
# | WHO&DIPSI | Greater or Equivalent 200        | Diabetes   |
#
# ## MRP &amp; USP:
#
# - o 1 st time in India
# - o In Veg form (Green Symbol)
# - o OGTT for GDM Screening in Pregnant women
#
# ## Competitors:
#
# ## ALL THE BEST!!
#
# <!-- image -->

# %%
# Save the extracted text as a Markdown file
with open("BIOS_1.md", "w", encoding="utf-8") as md_file:
    md_file.write(md)

# %% [markdown]
# ---

# %% [markdown]
# #### Extract Image and Tables with Markdown

# %%
# %pip install rapidocr_onnxruntime
# Out:
# Collecting rapidocr_onnxruntime
#   Downloading rapidocr_onnxruntime-1.4.4-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pyclipper>=1.2.0 in ./.venv/lib/python3.10/site-packages (from rapidocr_onnxruntime) (1.3.0.post6)
# Collecting opencv-python>=4.5.1.48 (from rapidocr_onnxruntime)
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.19.5 in ./.venv/lib/python3.10/site-packages (from rapidocr_onnxruntime) (2.2.4)
# Requirement already satisfied: six>=1.15.0 in ./.venv/lib/python3.10/site-packages (from rapidocr_onnxruntime) (1.17.0)
# Requirement already satisfied: Shapely!=2.0.4,>=1.7.1 in ./.venv/lib/python3.10/site-packages (from rapidocr_onnxruntime) (2.1.0)
# Requirement already satisfied: PyYAML in ./.venv/lib/python3.10/site-packages (from rapidocr_onnxruntime) (6.0.2)
# Requirement already satisfied: Pillow in ./.venv/lib/python3.10/site-packages (from rapidocr_onnxruntime) (10.4.0)
# Collecting onnxruntime>=1.7.0 (from rapidocr_onnxruntime)
#   Downloading onnxruntime-1.21.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.10/site-packages (from rapidocr_onnxruntime) (4.67.1)
# Collecting coloredlogs (from onnxruntime>=1.7.0->rapidocr_onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.7.0->rapidocr_onnxruntime)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from onnxruntime>=1.7.0->rapidocr_onnxruntime) (24.2)
# Collecting protobuf (from onnxruntime>=1.7.0->rapidocr_onnxruntime)
#   Downloading protobuf-6.30.2-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: sympy in ./.venv/lib/python3.10/site-packages (from onnxruntime>=1.7.0->rapidocr_onnxruntime) (1.13.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.7.0->rapidocr_onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from sympy->onnxruntime>=1.7.0->rapidocr_onnxruntime) (1.3.0)
# Downloading rapidocr_onnxruntime-1.4.4-py3-none-any.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 13.4 MB/s eta 0:00:00a 0:00:01
# Downloading onnxruntime-1.21.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 23.2 MB/s eta 0:00:00a 0:00:01
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 16.6 MB/s eta 0:00:0000:0100:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading protobuf-6.30.2-cp39-abi3-manylinux2014_x86_64.whl (316 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Installing collected packages: flatbuffers, protobuf, opencv-python, humanfriendly, coloredlogs, onnxruntime, rapidocr_onnxruntime
# Successfully installed coloredlogs-15.0.1 flatbuffers-25.2.10 humanfriendly-10.0 onnxruntime-1.21.0 opencv-python-4.11.0.86 protobuf-6.30.2 rapidocr_onnxruntime-1.4.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
import time
from pathlib import Path

from docling_core.types.doc import ImageRefMode, PictureItem, TableItem

from docling.backend.docling_parse_backend import DoclingParseDocumentBackend

from docling.datamodel.base_models import FigureElement, InputFormat, Table
from docling.datamodel.pipeline_options import PdfPipelineOptions, EasyOcrOptions, RapidOcrOptions
from docling.document_converter import DocumentConverter, PdfFormatOption

_log = logging.getLogger(__name__)

IMAGE_RESOLUTION_SCALE = 1.0

# %% [markdown]
# #### Any of the OCR options can be used:EasyOcrOptions, TesseractOcrOptions, TesseractCliOcrOptions, OcrMacOptions(Mac only), RapidOcrOptions
# ##### ocr_options = EasyOcrOptions(force_full_page_ocr=True)
# ##### ocr_options = TesseractOcrOptions(force_full_page_ocr=True)
# ##### ocr_options = OcrMacOptions(force_full_page_ocr=True)
# ##### ocr_options = RapidOcrOptions(force_full_page_ocr=True)
# ##### ocr_options = TesseractCliOcrOptions(force_full_page_ocr=True)

# %%
def main():
    logging.basicConfig(level=logging.INFO)

    input_doc_path = Path(r"/home/qb-admin/Desktop/ap/budget_speech_2025.pdf")
    output_dir = Path(r"/home/qb-admin/Desktop/ap/extracted_images")

    # Important: For operating with page images, we must keep them, otherwise the DocumentConverter
    # will destroy them for cleaning up memory.
    # This is done by setting PdfPipelineOptions.images_scale, which also defines the scale of images.
    # scale=1 correspond of a standard 72 DPI image
    # The PdfPipelineOptions.generate_* are the selectors for the document elements which will be enriched
    # with the image field
    pipeline_options = PdfPipelineOptions()
    pipeline_options.images_scale = IMAGE_RESOLUTION_SCALE
    pipeline_options.generate_page_images = True
    pipeline_options.generate_picture_images = True
    pipeline_options.do_ocr = True
    pipeline_options.do_table_structure = True
    pipeline_options.table_structure_options.do_cell_matching = True
    ocr_options = EasyOcrOptions(force_full_page_ocr=True)
    pipeline_options.ocr_options = ocr_options

    doc_converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
        }
    )

    start_time = time.time()

    conv_res = doc_converter.convert(input_doc_path)

    output_dir.mkdir(parents=True, exist_ok=True)
    doc_filename = conv_res.input.file.stem

    # Save page images
    for page_no, page in conv_res.document.pages.items():
        page_no = page.page_no
        page_image_filename = output_dir / f"{doc_filename}-{page_no}.png"
        with page_image_filename.open("wb") as fp:
            page.image.pil_image.save(fp, format="PNG")

    # Save images of figures and tables
    table_counter = 0
    picture_counter = 0
    for element, _level in conv_res.document.iterate_items():
        if isinstance(element, TableItem):
            table_counter += 1
            element_image_filename = (
                output_dir / f"{doc_filename}-table-{table_counter}.png"
            )
            with element_image_filename.open("wb") as fp:
                element.get_image(conv_res.document).save(fp, "PNG")

        if isinstance(element, PictureItem):
            picture_counter += 1
            element_image_filename = (
                output_dir / f"{doc_filename}-picture-{picture_counter}.png"
            )
            with element_image_filename.open("wb") as fp:
                element.get_image(conv_res.document).save(fp, "PNG")

    # Save markdown with embedded pictures
    # md_filename = output_dir / f"{doc_filename}-with-images.md"
    # conv_res.document.save_as_markdown(md_filename, image_mode=ImageRefMode.EMBEDDED)

    # Save markdown with externally referenced pictures
    md_filename = output_dir / f"{doc_filename}-with-image-refs.md"
    conv_res.document.save_as_markdown(md_filename, image_mode=ImageRefMode.REFERENCED)

    end_time = time.time() - start_time

    _log.info(f"Document converted and figures exported in {end_time:.2f} seconds.")

# %%
if __name__ == "__main__":
    main()
# Out:
# INFO:docling.document_converter:Going to convert document batch...
# INFO:docling.document_converter:Initializing pipeline for StandardPdfPipeline with options hash 3dc0cf0ba9d0223f58b4ea49c0396c77
# INFO:docling.models.factories.base_factory:Loading plugin 'docling_defaults'
# INFO:docling.models.factories:Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# INFO:docling.utils.accelerator_utils:Accelerator device: 'cuda:0'
# INFO:docling.utils.accelerator_utils:Accelerator device: 'cuda:0'
# INFO:docling.utils.accelerator_utils:Accelerator device: 'cuda:0'
# INFO:docling.models.factories.base_factory:Loading plugin 'docling_defaults'
# INFO:docling.models.factories:Registered picture descriptions: ['vlm', 'api']
# INFO:docling.pipeline.base_pipeline:Processing document budget_speech_2025.pdf
# INFO:docling.document_converter:Finished converting document budget_speech_2025.pdf in 246.25 sec.
# INFO:__main__:Document converted and figures exported in 250.11 seconds.

# %% [markdown]
# #### AnotherCustom conversion approach to covert pdf to markdown without storing images

# %%
import json
import logging
import time
from pathlib import Path

# %%
from docling.backend.pypdfium2_backend import PyPdfiumDocumentBackend
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import (
    AcceleratorDevice,
    AcceleratorOptions,
    PdfPipelineOptions,
)
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.models.ocr_mac_model import OcrMacOptions
from docling.models.tesseract_ocr_cli_model import TesseractCliOcrOptions
from docling.models.tesseract_ocr_model import TesseractOcrOptions

# %%
_log = logging.getLogger(__name__)

# %%
def main():
    logging.basicConfig(level=logging.INFO)

    input_doc_path = Path("/home/qb-admin/Desktop/ap/budget_speech_2025.pdf")

    ###########################################################################

    # The following sections contain a combination of PipelineOptions
    # and PDF Backends for various configurations.
    # Uncomment one section at the time to see the differences in the output.


    # PyPdfium with EasyOCR
    # -----------------
    # pipeline_options = PdfPipelineOptions()
    # pipeline_options.do_ocr = True
    # pipeline_options.do_table_structure = True
    # pipeline_options.table_structure_options.do_cell_matching = True

    # doc_converter = DocumentConverter(
    #     format_options={
    #         InputFormat.PDF: PdfFormatOption(
    #             pipeline_options=pipeline_options, backend=PyPdfiumDocumentBackend
    #         )
    #     }
    # )

    # Docling Parse without EasyOCR
    # -------------------------
    # pipeline_options = PdfPipelineOptions()
    # pipeline_options.do_ocr = False
    # pipeline_options.do_table_structure = True
    # pipeline_options.table_structure_options.do_cell_matching = True

    # doc_converter = DocumentConverter(
    #     format_options={
    #         InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    #     }
    # )

    # Docling Parse with EasyOCR
    # ----------------------
    pipeline_options = PdfPipelineOptions()
    pipeline_options.do_ocr = True
    pipeline_options.do_table_structure = True
    pipeline_options.table_structure_options.do_cell_matching = True
    # pipeline_options.ocr_options.lang = ["es"]
    pipeline_options.accelerator_options = AcceleratorOptions(
        num_threads=4, device=AcceleratorDevice.AUTO
    )

    doc_converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
        }
    )



    ###########################################################################

    start_time = time.time()
    conv_result = doc_converter.convert(input_doc_path)
    end_time = time.time() - start_time

    _log.info(f"Document converted in {end_time:.2f} seconds.")

    ## Export results
    output_dir = Path("scratch")
    output_dir.mkdir(parents=True, exist_ok=True)
    doc_filename = conv_result.input.file.stem

    # Export Deep Search document JSON format:
    # with (output_dir / f"{doc_filename}.json").open("w", encoding="utf-8") as fp:
    #     fp.write(json.dumps(conv_result.document.export_to_dict()))

    # Export Text format:
    with (output_dir / f"{doc_filename}.txt").open("w", encoding="utf-8") as fp:
        fp.write(conv_result.document.export_to_text())

    # Export Markdown format:
    with (output_dir / f"{doc_filename}.md").open("w", encoding="utf-8") as fp:
        fp.write(conv_result.document.export_to_markdown())

    # Export Document Tags format:
    # with (output_dir / f"{doc_filename}.doctags").open("w", encoding="utf-8") as fp:
    #     fp.write(conv_result.document.export_to_document_tokens())

# %%
if __name__ == "__main__":
    main()
# Out:
# INFO:docling.document_converter:Going to convert document batch...
# INFO:docling.document_converter:Initializing pipeline for StandardPdfPipeline with options hash b6c066811298ccb7b6ca58fb8cfe4c84
# INFO:docling.models.factories.base_factory:Loading plugin 'docling_defaults'
# INFO:docling.models.factories:Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# INFO:docling.utils.accelerator_utils:Accelerator device: 'cuda:0'
# INFO:docling.utils.accelerator_utils:Accelerator device: 'cuda:0'
# INFO:docling.utils.accelerator_utils:Accelerator device: 'cuda:0'
# INFO:docling.models.factories.base_factory:Loading plugin 'docling_defaults'
# INFO:docling.models.factories:Registered picture descriptions: ['vlm', 'api']
# INFO:docling.pipeline.base_pipeline:Processing document budget_speech_2025.pdf
# INFO:docling.document_converter:Finished converting document budget_speech_2025.pdf in 46.40 sec.
# INFO:__main__:Document converted in 46.40 seconds.
# WARNING:docling_core.types.doc.document:Parameter `strict_text` has been deprecated and will be ignored.
